# %% [markdown]
# ##Motaplotlib

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [2,4,1,5,3]
plt.title("Line Graph")
plt.xlabel("Height")
plt.ylabel("Weight")

plt.plot(x,y)
plt.show()
