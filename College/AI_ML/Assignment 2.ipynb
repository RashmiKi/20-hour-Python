# %% [markdown]
# # Assignment 2 - Simple Linear Regression and Multiple Linear Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model
from sklearn import datasets

# %%
data = datasets.fetch_california_housing()

# %%
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] =data.target

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
X = df[['Population']]   # independent variable
y = df['target']  # dependent variable

# %%
plt.scatter(X, y)

# %%
m = linear_model.LinearRegression()
m.fit(X, y)
# Out:
# LinearRegression()

# %%
m.intercept_
# Out:
# np.float64(2.1043626207627333)

# %%
m.coef_[0]
# Out:
# np.float64(-2.5117527746150814e-05)

# %%
y_pred = m.predict(X)

# %%
# Plot actual vs predicted
plt.scatter(X, y, color='blue', label='Actual data')
plt.plot(X, y_pred, color='red', label='Regression line')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Simple Linear Regression')
plt.legend()
plt.show()

# %%
m.predict([[0.06]])
# Out:
# c:\Users\Rashmi\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.10436111])

# %%
m.predict([[0.13]])
# Out:
# c:\Users\Rashmi\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.10435936])

# %% [markdown]
# # Multiple Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn import datasets

# %%
calfornia = datasets.fetch_california_housing()

# %%
df = pd.DataFrame(calfornia.data, columns=calfornia.feature_names)
df['target'] =data.target

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
X = df[calfornia.feature_names]   # independent variable
y = df['target']  # dependent variable

# %%
m = linear_model.LinearRegression()
m.fit(X, y)
# Out:
# LinearRegression()

# %%
m.coef_
# Out:
# array([ 4.36693293e-01,  9.43577803e-03, -1.07322041e-01,  6.45065694e-01,
#        -3.97638942e-06, -3.78654265e-03, -4.21314378e-01, -4.34513755e-01])

# %%
m.intercept_
# Out:
# np.float64(-36.94192020718454)

# %%
print("R^2 Score:", round(m.score(X,y)),3)
# Out:
# R^2 Score: 1 3

# %%
y1_pred = m.predict(X)

# %%
plt.scatter(y, y1_pred, color="purple")
plt.show()
